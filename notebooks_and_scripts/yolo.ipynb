# %%
# !yolo detect train model=/Users/michaelrice/Documents/GitHub/Thesis/MSc_AI_Thesis/other/yolo11n.pt data=/Users/michaelrice/Documents/GitHub/Thesis/MSc_AI_Thesis/data/yolov11_datasetv2/data.yaml epochs=7 imgsz=512 device=mps
# Out:
# ...
# 100%|██████████████████████████████████████| 5.35M/5.35M [00:00<00:00, 30.2MB/s]
# New https://pypi.org/project/ultralytics/8.3.152 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.100 🚀 Python-3.11.12 torch-2.6.0 MPS (Apple M4)
# ...

# %%
#image test
from ultralytics import YOLO
import os 


model = YOLO('/Users/michaelrice/Documents/GitHub/Thesis/MSc_AI_Thesis/runs/detect/datasetv2_yolov11/weights/best.pt')

images = os.listdir('/Users/michaelrice/Documents/GitHub/Thesis/MSc_AI_Thesis/data/yolov11_datasetv2/test/images')
for image in images:
    results = model.predict(source=f'/Users/michaelrice/Documents/GitHub/Thesis/MSc_AI_Thesis/data/yolov11_datasetv2/test/images/{image}', save=True, save_txt=True, save_conf=True)
    results[0].show()  # Display the image with predictions
# Out:
# image 1/1 /Users/michaelrice/Documents/GitHub/Thesis/MSc_AI_Thesis/data/yolov11_datasetv2/test/images/frame_75_jpg.rf.8514966636a3c38e9bd582ca822b6791.jpg: 512x512 1 Mobile Phone, 1 Rearview Mirror, 1 Right Wing Mirror, 1 Steering Wheel, 39.7ms
# Speed: 0.6ms preprocess, 39.7ms inference, 3.1ms postprocess per image at shape (1, 3, 512, 512)
# Results saved to /Users/michaelrice/Documents/GitHub/Thesis/MSc_AI_Thesis/runs/detect/predict
# 1 label saved to /Users/michaelrice/Documents/GitHub/Thesis/MSc_AI_Thesis/runs/detect/predict/labels
#
# image 1/1 /Users/michaelrice/Documents/GitHub/Thesis/MSc_AI_Thesis/data/yolov11_datasetv2/test/images/frame_69_jpg.rf.9b4f7d1c155b1119667c17c152c379c4.jpg: 512x512 1 Mobile Phone, 1 Rearview Mirror, 1 Right Wing Mirror, 1 Steering Wheel, 45.1ms
# Speed: 0.9ms preprocess, 45.1ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 512)
# Results saved to /Users/michaelrice/Documents/GitHub/Thesis/MSc_AI_Thesis/runs/detect/predict
# ...

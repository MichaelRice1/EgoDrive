# %%
# !yolo detect train model=/Users/michaelrice/Documents/GitHub/Thesis/MSc_AI_Thesis/utilities/yolo11n.pt data=/Users/michaelrice/Documents/GitHub/Thesis/MSc_AI_Thesis/data/incabin_object_detection_datasets/in_cabin_object_det_6_yv11/data.yaml epochs=20 imgsz=512 device=mps
# Out:
# New https://pypi.org/project/ultralytics/8.3.161 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.100 🚀 Python-3.11.12 torch-2.6.0 MPS (Apple M4)
# ...

# %%
# !yolo detect train model=/Users/michaelrice/Documents/GitHub/Thesis/MSc_AI_Thesis/utilities/yolo11n.pt data=/Users/michaelrice/Documents/GitHub/Thesis/MSc_AI_Thesis/data/incabin_object_detection_datasets/in_cabin_object_det5/data.yaml epochs=20 imgsz=512 batch=16 name=yolov11-v3
# Out:
# New https://pypi.org/project/ultralytics/8.3.159 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.100 🚀 Python-3.11.12 torch-2.6.0 CPU (Apple M4)
# ...

# %%
# !yolo pose val model=/Users/michaelrice/Documents/GitHub/Thesis/MSc_AI_Thesis/runs/pose/train/weights/best.pt data=/Users/michaelrice/Documents/GitHub/Thesis/MSc_AI_Thesis/data/incabin_object_detection_datasets/steeringwheelangle-2/data.yaml split=test
# Out:
# Ultralytics 8.3.100 🚀 Python-3.11.12 torch-2.6.0 CPU (Apple M4)
# YOLOv8s-pose summary (fused): 81 layers, 11,413,344 parameters, 0 gradients, 29.4 GFLOPs
# val: Scanning /Users/michaelrice/Documents/GitHub/Thesis/MSc_AI_Thesis/data/inca
# val: New cache created: /Users/michaelrice/Documents/GitHub/Thesis/MSc_AI_Thesis/data/incabin_object_detection_datasets/steeringwheelangle-2/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         15         11      0.843          1       0.86      0.839      0.843          1       0.86      0.733
# Speed: 0.2ms preprocess, 31.2ms inference, 0.0ms loss, 0.3ms postprocess per image
# Results saved to /Users/michaelrice/Documents/GitHub/Thesis/MSc_AI_Thesis/runs/pose/val2
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
#image test
from ultralytics import YOLO
import os 


model = YOLO('/Users/michaelrice/Documents/GitHub/Thesis/MSc_AI_Thesis/runs/detect/train2/weights/best.pt')

images = os.listdir('/Users/michaelrice/Documents/GitHub/Thesis/MSc_AI_Thesis/data/yolov11_datasetv2/test/images')
for image in images:
    results = model.predict(source=f'/Users/michaelrice/Documents/GitHub/Thesis/MSc_AI_Thesis/data/yolov11_datasetv2/test/images/{image}', save=True, save_txt=True, save_conf=True)
    results[0].show()  # Display the image with predictions
# Out:
# image 1/1 /Users/michaelrice/Documents/GitHub/Thesis/MSc_AI_Thesis/data/yolov11_datasetv2/test/images/frame_75_jpg.rf.8514966636a3c38e9bd582ca822b6791.jpg: 512x512 2 Mobile Phones, 1 Rearview Mirror, 1 Right Wing Mirror, 2 Steering Wheels, 38.8ms
# Speed: 0.8ms preprocess, 38.8ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 512)
# Results saved to /Users/michaelrice/Documents/GitHub/Thesis/MSc_AI_Thesis/runs/detect/predict3
# 1 label saved to /Users/michaelrice/Documents/GitHub/Thesis/MSc_AI_Thesis/runs/detect/predict3/labels
#
# image 1/1 /Users/michaelrice/Documents/GitHub/Thesis/MSc_AI_Thesis/data/yolov11_datasetv2/test/images/frame_69_jpg.rf.9b4f7d1c155b1119667c17c152c379c4.jpg: 512x512 1 Gear Stick, 1 Rearview Mirror, 1 Right Wing Mirror, 53.7ms
# Speed: 1.7ms preprocess, 53.7ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 512)
# Results saved to /Users/michaelrice/Documents/GitHub/Thesis/MSc_AI_Thesis/runs/detect/predict3
# ...

# %%
!

# %%
# !pip install plotly
# !pip install src

import numpy as np
from scipy.spatial.transform import Rotation

import plotly.graph_objects as go

from src.data.language_sequence import LanguageSequence
from src.data.point_cloud import PointCloud
from src.networks.scenescript_model import SceneScriptWrapper
# Out:
# Collecting plotly
#   Downloading plotly-6.0.0-py3-none-any.whl.metadata (5.6 kB)
# Collecting narwhals>=1.15.1 (from plotly)
#   Downloading narwhals-1.30.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging in c:\users\athen\desktop\github\mastersthesis\.venv\lib\site-packages (from plotly) (24.2)
# Downloading plotly-6.0.0-py3-none-any.whl (14.8 MB)
#    ---------------------------------------- 0.0/14.8 MB ? eta -:--:--
#    ---------------------------------------  14.7/14.8 MB 103.0 MB/s eta 0:00:01
#    ---------------------------------------  14.7/14.8 MB 103.0 MB/s eta 0:00:01
#    ---------------------------------------- 14.8/14.8 MB 30.0 MB/s eta 0:00:00
# Downloading narwhals-1.30.0-py3-none-any.whl (313 kB)
# Installing collected packages: narwhals, plotly
# Successfully installed narwhals-1.30.0 plotly-6.0.0
# Collecting src
#   Downloading src-0.0.7.zip (6.3 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Building wheels for collected packages: src
#   Building wheel for src (pyproject.toml): started
#   Building wheel for src (pyproject.toml): finished with status 'error'
# Failed to build src
#   error: subprocess-exited-with-error
#
#   × Building wheel for src (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [71 lines of output]
#       C:\Users\athen\AppData\Local\Temp\pip-build-env-dgglwv3b\overlay\Lib\site-packages\setuptools\_distutils\dist.py:289: UserWarning: Unknown distribution option: 'tests_require'
#         warnings.warn(msg)
#       running bdist_wheel
#       running build
#       running build_py
#       creating build\lib\src
#       copying src\__init__.py -> build\lib\src
#       running egg_info
#       writing src.egg-info\PKG-INFO
#       writing dependency_links to src.egg-info\dependency_links.txt
#       writing requirements to src.egg-info\requires.txt
#       writing top-level names to src.egg-info\top_level.txt
#       reading manifest file 'src.egg-info\SOURCES.txt'
#       reading manifest template 'MANIFEST.in'
#       adding license file 'LICENSE.rst'
#       writing manifest file 'src.egg-info\SOURCES.txt'
#       Traceback (most recent call last):
#         File "c:\Users\athen\Desktop\Github\MastersThesis\.venv\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 389, in <module>
#           main()
#         File "c:\Users\athen\Desktop\Github\MastersThesis\.venv\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 373, in main
#           json_out["return_val"] = hook(**hook_input["kwargs"])
#                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "c:\Users\athen\Desktop\Github\MastersThesis\.venv\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 280, in build_wheel
#           return _build_backend().build_wheel(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\athen\AppData\Local\Temp\pip-build-env-dgglwv3b\overlay\Lib\site-packages\setuptools\build_meta.py", line 438, in build_wheel
#           return _build(['bdist_wheel', '--dist-info-dir', str(metadata_directory)])
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\athen\AppData\Local\Temp\pip-build-env-dgglwv3b\overlay\Lib\site-packages\setuptools\build_meta.py", line 426, in _build
#           return self._build_with_temp_dir(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\athen\AppData\Local\Temp\pip-build-env-dgglwv3b\overlay\Lib\site-packages\setuptools\build_meta.py", line 407, in _build_with_temp_dir
#           self.run_setup()
#         File "C:\Users\athen\AppData\Local\Temp\pip-build-env-dgglwv3b\overlay\Lib\site-packages\setuptools\build_meta.py", line 522, in run_setup
#           super().run_setup(setup_script=setup_script)
#         File "C:\Users\athen\AppData\Local\Temp\pip-build-env-dgglwv3b\overlay\Lib\site-packages\setuptools\build_meta.py", line 320, in run_setup
#           exec(code, locals())
#         File "<string>", line 70, in <module>
#         File "C:\Users\athen\AppData\Local\Temp\pip-build-env-dgglwv3b\overlay\Lib\site-packages\setuptools\__init__.py", line 117, in setup
#           return distutils.core.setup(**attrs)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\athen\AppData\Local\Temp\pip-build-env-dgglwv3b\overlay\Lib\site-packages\setuptools\_distutils\core.py", line 186, in setup
#           return run_commands(dist)
#                  ^^^^^^^^^^^^^^^^^^
#         File "C:\Users\athen\AppData\Local\Temp\pip-build-env-dgglwv3b\overlay\Lib\site-packages\setuptools\_distutils\core.py", line 202, in run_commands
#           dist.run_commands()
#         File "C:\Users\athen\AppData\Local\Temp\pip-build-env-dgglwv3b\overlay\Lib\site-packages\setuptools\_distutils\dist.py", line 1002, in run_commands
#           self.run_command(cmd)
#         File "C:\Users\athen\AppData\Local\Temp\pip-build-env-dgglwv3b\overlay\Lib\site-packages\setuptools\dist.py", line 999, in run_command
#           super().run_command(command)
#         File "C:\Users\athen\AppData\Local\Temp\pip-build-env-dgglwv3b\overlay\Lib\site-packages\setuptools\_distutils\dist.py", line 1021, in run_command
#           cmd_obj.run()
#         File "C:\Users\athen\AppData\Local\Temp\pip-build-env-dgglwv3b\overlay\Lib\site-packages\setuptools\command\bdist_wheel.py", line 371, in run
#           install = self.reinitialize_command("install", reinit_subcommands=True)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\athen\AppData\Local\Temp\pip-build-env-dgglwv3b\overlay\Lib\site-packages\setuptools\__init__.py", line 225, in reinitialize_command
#           cmd = _Command.reinitialize_command(self, command, reinit_subcommands)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\athen\AppData\Local\Temp\pip-build-env-dgglwv3b\overlay\Lib\site-packages\setuptools\_distutils\cmd.py", line 350, in reinitialize_command
#           return self.distribution.reinitialize_command(command, reinit_subcommands)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\athen\AppData\Local\Temp\pip-build-env-dgglwv3b\overlay\Lib\site-packages\setuptools\_distutils\dist.py", line 986, in reinitialize_command
#           for sub in command.get_sub_commands():
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\athen\AppData\Local\Temp\pip-build-env-dgglwv3b\overlay\Lib\site-packages\setuptools\_distutils\cmd.py", line 368, in get_sub_commands
#           if method is None or method(self):
#                                ^^^^^^^^^^^^
#         File "C:\Users\athen\AppData\Local\Temp\pip-build-env-dgglwv3b\overlay\Lib\site-packages\setuptools\_distutils\command\install.py", line 788, in has_lib
#           self.distribution.has_pure_modules() or self.distribution.has_ext_modules()
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#       AttributeError: 'NoneType' object has no attribute 'has_pure_modules'
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for src
# ERROR: Failed to build installable wheels for some pyproject.toml based projects (src)
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 9
#       5 from scipy.spatial.transform import Rotation
#       7 import plotly.graph_objects as go
# ----> 9 from src.data.language_sequence import LanguageSequence
#      10 from src.data.point_cloud import PointCloud
#      11 from src.networks.scenescript_model import SceneScriptWrapper
#
# ModuleNotFoundError: No module named 'src'
